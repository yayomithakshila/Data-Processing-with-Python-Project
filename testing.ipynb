# %% [markdown]
# # Analyzing Work Place Satisfaction Survey Data
#
# This notebook walks through an analysis of workplace satisfaction survey data. The dataset includes demographic variables (such as gender, age, and family status), educational background, years of service, and salary. Additionally, the data captures satisfaction ratings for management, colleagues, the work environment, salary, and job tasks. Other variables indicate whether the respondent has used various company benefits such as healthcare, gym access, holiday cabins, and massage services.
#
# We'll perform data cleaning, explore descriptive statistics, visualize the data, and investigate relationships between variables using cross-tabulation, statistical tests, and visualizations.
#
# ## Goals of the analysis:
# 1.Understand the demographics and job-related attributes of the respondents.
# 2.Analyze satisfaction levels across different groups, such as gender, education level, and family status.
# 3.Examine the relationships between satisfaction ratings and variables like salary, years of service, and company benefits.
# 4.Test for significant relationships between key variables (e.g., satisfaction with management and use of healthcare services).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Initial Preparation
# #### Load the data
# In this section, we'll start by importing the necessary libraries and loading the data. We'll take an initial look at the dataset to understand its structure and contents.

# %% [markdown]
# Here we use the `head()` function to display the first five rows of the dataset, which helps us quickly understand the variables available and how the data is structured.
#
# Use isnull().sum() to check for missing values in each column. This will help in identifying which columns require data cleaning.

# %%
# Open the data
df = pd.read_excel('WorkPlaceSatisfactionSurveyData.xlsx')
df.head()
# Out:
#    number  gender  age  family  education  years_of_service  salary  \
# 0       1       1   38       1        1.0              22.0    3587
# 1       2       1   29       2        2.0              10.0    2963
# 2       3       1   30       1        1.0               7.0    1989
# 3       4       1   36       2        1.0              14.0    2144
# 4       5       1   24       1        2.0               4.0    2183
#
#    sat_management  sat_colleques  sat_workingEnvironment  sat_salary  \
# 0               3            3.0                       3           3
# 1               1            5.0                       2           1
# 2               3            4.0                       1           1
# 3               3            3.0                       3           3
# 4               2            3.0                       2           1
#
#    sat_tasks  healtcare  holidayCabin  gym  muscleCare
# 0          3        NaN           NaN  NaN         NaN
# ...

# %%
# Check for missing values in each column
df.isnull().sum()
# Out:
# number                     0
# gender                     0
# age                        0
# family                     0
# education                  1
# years_of_service           2
# salary                     0
# sat_management             0
# sat_colleques              1
# sat_workingEnvironment     0
# sat_salary                 0
# sat_tasks                  0
# healtcare                 35
# holidayCabin              62
# gym                       73
# muscleCare                60
# dtype: int64

# %% [markdown]
# #### Adjust column names
# Step 1:Here we will replace the column names with new names.
#
# Step 2:We will drop unnecessary columns or rows as needed using drop().

# %%
#Rrename all columns
df.columns = ['Number ', 'Gender', 'Age','Marital status','Education Level','Service years','Salary','Sat_Management',
              'Sat_Colleques','Sat_WorkEnvironment','Sat_Salary','Sat_Tasks','HealthCare','Holiday Cottage','Gym','MuscleCare']

# %%
#Print the table with renamed all columns
df.head()
# Out:
#    Number   Gender  Age  Marital status  Education Level  Service years  \
# 0        1       1   38               1              1.0           22.0
# 1        2       1   29               2              2.0           10.0
# 2        3       1   30               1              1.0            7.0
# 3        4       1   36               2              1.0           14.0
# 4        5       1   24               1              2.0            4.0
#
#    Salary  Sat_Management  Sat_Colleques  Sat_WorkEnvironment  Sat_Salary  \
# 0    3587               3            3.0                    3           3
# 1    2963               1            5.0                    2           1
# 2    1989               3            4.0                    1           1
# 3    2144               3            3.0                    3           3
# 4    2183               2            3.0                    2           1
#
#    Sat_Tasks  HealthCare  Holiday Cottage  Gym  MuscleCare
# ...

# %%
# Print the renamed column names
print(df.columns)
# Out:
# Index(['Number ', 'Gender', 'Age', 'Marital status', 'Education Level',
#        'Service years', 'Salary', 'Sat_Management', 'Sat_Colleques',
#        'Sat_WorkEnvironment', 'Sat_Salary', 'Sat_Tasks', 'HealthCare',
#        'Holiday Cottage', 'Gym', 'MuscleCare'],
#       dtype='object')

# %%
#Drop unnecessary columns or rows as needed using drop()
df = df.drop(['Number ', 'HealthCare', 'Holiday Cottage', 'Gym', 'MuscleCare'], axis=1)

# %%
# Print the column names and table
print(df.columns)
df.head()
# Out:
# Index(['Gender', 'Age', 'Marital status', 'Education Level', 'Service years',
#        'Salary', 'Sat_Management', 'Sat_Colleques', 'Sat_WorkEnvironment',
#        'Sat_Salary', 'Sat_Tasks'],
#       dtype='object')
#    Gender  Age  Marital status  Education Level  Service years  Salary  \
# 0       1   38               1              1.0           22.0    3587
# 1       1   29               2              2.0           10.0    2963
# 2       1   30               1              1.0            7.0    1989
# 3       1   36               2              1.0           14.0    2144
# 4       1   24               1              2.0            4.0    2183
#
#    Sat_Management  Sat_Colleques  Sat_WorkEnvironment  Sat_Salary  Sat_Tasks
# 0               3            3.0                    3           3          3
# 1               1            5.0                    2           1          3
# 2               3            4.0                    1           1          3
# ...

# %% [markdown]
# #### Get summary statistics
# Step1:Use commands like info(), describe(), count(), nlargest().
#
# Step2:Loop through variables to explore unique values:for var in df: print(var, df[var].unique())

# %%
#info(): Shows a summary of the DataFrame, including how many rows and columns it has, the data types, and if there are any missing values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               82 non-null     int64
#  1   Age                  82 non-null     int64
#  2   Marital status       82 non-null     int64
#  3   Education Level      81 non-null     float64
#  4   Service years        80 non-null     float64
#  5   Salary               82 non-null     int64
#  6   Sat_Management       82 non-null     int64
#  7   Sat_Colleques        81 non-null     float64
#  8   Sat_WorkEnvironment  82 non-null     int64
#  9   Sat_Salary           82 non-null     int64
#  10  Sat_Tasks            82 non-null     int64
# dtypes: float64(3), int64(8)
# memory usage: 7.2 KB

# %%
#describe(): Gives basic statistics for numerical columns, like average, minimum, maximum, and how many entries there are.
df.describe()
# Out:
#           Gender        Age  Marital status  Education Level  Service years  \
# count  82.000000  82.000000       82.000000        81.000000      80.000000
# mean    1.231707  37.951220        1.621951         1.987654      12.175000
# std     0.424519   9.773866        0.487884         0.844006       8.807038
# min     1.000000  20.000000        1.000000         1.000000       0.000000
# 25%     1.000000  31.000000        1.000000         1.000000       3.750000
# 50%     1.000000  37.500000        2.000000         2.000000      12.500000
# 75%     1.000000  44.000000        2.000000         3.000000      18.250000
# max     2.000000  61.000000        2.000000         4.000000      36.000000
#
#             Salary  Sat_Management  Sat_Colleques  Sat_WorkEnvironment  \
# count    82.000000       82.000000      81.000000            82.000000
# mean   2563.878049        3.060976       4.061728             3.219512
# ...

# %%
#count(): Tells  how many non-empty entries there are in each column, helping to find missing data.
df.count()
# Out:
# Gender                 82
# Age                    82
# Marital status         82
# Education Level        81
# Service years          80
# Salary                 82
# Sat_Management         82
# Sat_Colleques          81
# Sat_WorkEnvironment    82
# Sat_Salary             82
# Sat_Tasks              82
# dtype: int64

# %%
#nlargest(n, 'column_name'): Shows the top n highest values in a specific column (like the highest salaries).
df.nlargest(10, 'Salary')
# Out:
#     Gender  Age  Marital status  Education Level  Service years  Salary  \
# 32       1   59               2              3.0           15.0    6278
# 16       1   26               1              4.0            2.0    5225
# 66       1   37               2              4.0            8.0    5069
# 21       1   47               2              3.0           17.0    4874
# 23       1   36               1              3.0            7.0    4446
# 0        1   38               1              1.0           22.0    3587
# 13       1   58               2              3.0           21.0    3587
# 22       1   44               2              1.0           27.0    3510
# 68       1   28               2              2.0            1.0    3510
# 71       1   46               2              2.0           23.0    3470
#
#     Sat_Management  Sat_Colleques  Sat_WorkEnvironment  Sat_Salary  Sat_Tasks
# 32               4            4.0                    5           4          4
# ...

# %%
# Loop through each column in the DataFrame, prints each column name and its unique values from the DataFrame.
for var in df:
    print(var, df[var].unique())
# Out:
# Gender [1 2]
# Age [38 29 30 36 24 31 49 55 40 33 39 35 58 53 42 26 47 44 43 56 21 45 59 37
#  28 50 32 51 22 34 27 41 25 61 20 52 46]
# Marital status [1 2]
# Education Level [ 1.  2.  3.  4. nan]
# Service years [22. 10.  7. 14.  4. 16.  0. 23. 21. 15. 12.  2. 17. 20. 13. 27.  1.  3.
#  nan 24.  5.  9.  6. 35. 28. 18. 36. 19.  8.]
# Salary [3587 2963 1989 2144 2183 1910 2066 2768 2106 2651 2846 2808 3393 2691
#  5225 2729 2925 2457 4874 3510 4446 1521 2223 1949 2340 6278 1559 2027
#  2300 2534 1872 2261 2417 3119 2574 1715 5069 2495 3470 1598 1638 2612]
# Sat_Management [3 1 2 4 5]
# Sat_Colleques [ 3.  5.  4.  2. nan]
# Sat_WorkEnvironment [3 2 1 5 4]
# Sat_Salary [3 1 2 4 5]
# Sat_Tasks [3 2 4 1 5]

# %% [markdown]
# #### Clean the data by handling missing values and other issues

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Gender                 0
# Age                    0
# Marital status         0
# Education Level        1
# Service years          2
# Salary                 0
# Sat_Management         0
# Sat_Colleques          1
# Sat_WorkEnvironment    0
# Sat_Salary             0
# Sat_Tasks              0
# dtype: int64

# %%
# Only a few data points are missing in the dataset: there is one missing value in the `Education Level` column, 
# two missing values in the `Service years` column, and one missing value in the `Sat_Colleques` column. All other columns have no missing values.

# Fill missing values for 'Education Level' with 'Unknown'
df['Education Level'] = df['Education Level'].fillna('Unknown')

# Fill missing values for 'Service years' with the mean of the column
df['Service years'] = df['Service years'].fillna(df['Service years'].mean())

# Fill missing values for 'Sat_Colleques' with the mean of the column
df['Sat_Colleques'] = df['Sat_Colleques'].fillna(df['Sat_Colleques'].mean())

# Check for missing values again to confirm all are filled
print(df.isnull().sum())
# Out:
# Gender                 0
# Age                    0
# Marital status         0
# Education Level        0
# Service years          0
# Salary                 0
# Sat_Management         0
# Sat_Colleques          0
# Sat_WorkEnvironment    0
# Sat_Salary             0
# Sat_Tasks              0
# dtype: int64

# %%
# Verify there is no missing values in each column
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Gender                 0
# Age                    0
# Marital status         0
# Education Level        0
# Service years          0
# Salary                 0
# Sat_Management         0
# Sat_Colleques          0
# Sat_WorkEnvironment    0
# Sat_Salary             0
# Sat_Tasks              0
# dtype: int64

# %% [markdown]
# ##### Examine Variable Distributions

# %% [markdown]
# Identify variable types.
# - Categorical/Qualitative
# - Numerical/Quantitative

# %%
# Identify categorical and numerical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Print categorical columns
print("Categorical Variables:")
for col in categorical_cols:
    print(col)

# Print numerical columns
print("\nNumerical Variables:")
for col in numerical_cols:
    print(col)
# Out:
# Categorical Variables:
# Education Level
#
# Numerical Variables:
# Gender
# Age
# Marital status
# Service years
# Salary
# Sat_Management
# Sat_Colleques
# Sat_WorkEnvironment
# Sat_Salary
# Sat_Tasks

# %% [markdown]
# While Gender, Age, Service Years, and Salary are typically considered numerical variables, the satisfaction measures (Sat_Management, Sat_Colleagues, Sat_Work Environment, Sat_Salary, and Sat_Tasks) are also categorical variables. These satisfaction measures utilize an opinion scale to assess respondents' perceptions.

# %%
# Define explicit lists for categorical, opinion scale, and numerical columns
categorical_cols = ['gender', 'family', 'education']  # Explicit categorical variables
numerical_cols = ['age', 'years_of_service', 'salary']  # Explicit numerical variables

# Define the satisfaction/opinion scale columns pattern (those starting with 'sat_')
satisfaction_prefix = 'Sat_'
satisfaction_cols = [col for col in df.columns if col.startswith(satisfaction_prefix)]

# Remove satisfaction columns from categorical columns to avoid duplication
categorical_cols = [col for col in categorical_cols if col not in satisfaction_cols]

# Print the categorical variables and their possible encodings
print("Categorical Variables and Encoding:")
for col in categorical_cols:
    if col == 'gender':
        print(f"{col} (1=male, 2=female)")
    elif col == 'family':
        print(f"{col} (1=single, 2=not single)")
    elif col == 'education':
        print(f"{col} (1=primary school, 2=secondary school graduate, 3=bachelor level, 4=master level)")
    else:
        print(col)

# Print the opinion scale variables and their scale
print("\nVariables using Opinion Scale (1=very unsatisfied, 5=very satisfied):")
for col in satisfaction_cols:
    print(col)

# Print the numerical variables
print("\nNumerical Variables:")
for col in numerical_cols:
    print(col)
# Out:
# Categorical Variables and Encoding:
# gender (1=male, 2=female)
# family (1=single, 2=not single)
# education (1=primary school, 2=secondary school graduate, 3=bachelor level, 4=master level)
#
# Variables using Opinion Scale (1=very unsatisfied, 5=very satisfied):
# Sat_Management
# Sat_Colleques
# Sat_WorkEnvironment
# Sat_Salary
# Sat_Tasks
#
# Numerical Variables:
# age
# years_of_service
# salary

# %% [markdown]
# ##### Analyze Numerical Variables

# %% [markdown]
# Descriptive Statistics for Numerical Variables
# - Descriptive statistics for numerical variables summarize key characteristics of the data, such as the **mean** (average), **standard deviation** (how much values vary), **minimum** (smallest value), and **maximum** (largest value). These statistics help provide a quick overview of the data's central tendency and spread, making it easier to understand and analyze the dataset.

# %%
# Define the numerical columns (ensure these names match your DataFrame)
numerical_cols = ['Age', 'Service years', 'Salary']  

# Use describe() to get the statistics for the numerical columns
numerical_describe = df[numerical_cols].describe()

# Print the descriptive statistics
print("Descriptive Statistics for Numerical Variables:")
print(numerical_describe)

# Option to change pandas display settings to avoid truncation
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)  
pd.set_option('display.width', None)  
pd.set_option('display.max_colwidth', None)
# Out:
# Descriptive Statistics for Numerical Variables:
#              Age  Service years       Salary
# count  82.000000       82.00000    82.000000
# mean   37.951220       12.17500  2563.878049
# std     9.773866        8.69763   849.350302
# min    20.000000        0.00000  1521.000000
# 25%    31.000000        4.25000  2027.000000
# 50%    37.500000       12.17500  2320.000000
# 75%    44.000000       18.00000  2808.000000
# max    61.000000       36.00000  6278.000000

# %% [markdown]
# Age Variable

# %%
# Analyze Age
age_col = 'Age'

# Histogram for Age
plt.figure(figsize=(8, 6))
sns.histplot(df[age_col], bins=10, kde=True)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Box Plot for Age
plt.figure(figsize=(6, 4))
sns.boxplot(x=df[age_col])
plt.title('Box Plot of Age')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# Service years Variable

# %%
# Analyze Years of Service
years_of_service_col = 'Service years'

# Histogram for Years of Service
plt.figure(figsize=(8, 6))
sns.histplot(df[years_of_service_col], bins=10, kde=True)
plt.title('Histogram of Service Years')
plt.xlabel('Service years')
plt.ylabel('Frequency')
plt.show()

# Box Plot for Years of Service
plt.figure(figsize=(6, 4))
sns.boxplot(x=df[years_of_service_col])
plt.title('Box Plot of Service years')
plt.xlabel('Service years')
plt.show()

# Prepare data for area plot
salary_cumsum = df['Salary'].cumsum().sort_values()
years_of_service_sorted = df['Service years'].sort_values()

# %% [markdown]
# Salary Variable

# %%
# Analyze Salary
salary_col = 'Salary'

# Histogram for Salary
plt.figure(figsize=(8, 6))
sns.histplot(df[salary_col], bins=10, kde=True)
plt.title('Histogram of Salary')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# Box Plot for Salary
plt.figure(figsize=(6, 4))
sns.boxplot(x=df[salary_col])
plt.title('Box Plot of Salary')
plt.xlabel('Salary')
plt.show()

# %% [markdown]
# Scatter plot for Age vs Salary

# %%
# Scatter plot of Age vs Salary
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Age', y=salary_col, alpha=0.7)  # Corrected 'Age' to match the DataFrame
plt.title('Scatter Plot of Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# Line plot for Average salary vs. service years

# %%
average_salary = df.groupby('Service years')['Salary'].mean().reset_index()

# Create a line plot for average salary vs. service years
plt.figure(figsize=(12, 6))  # Increase figure size for better readability
sns.lineplot(data=average_salary, x='Service years', y='Salary', marker='o')

# Improve x-axis labels clarity
plt.title('Average Salary by Service Years')
plt.xlabel('Service Years')
plt.ylabel('Average Salary')
plt.grid()

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)  # Rotate labels to avoid overlap
plt.tight_layout()  # Adjust layout to make room for rotated labels

plt.show()

# %% [markdown]
# Area chart for Salary Distribution by Gender

# %%
# Count the occurrences of each unique value in the 'Service years' column
service_years_counts = df['Service years'].value_counts().sort_index()

# Create a DataFrame for plotting
service_years_df = pd.DataFrame(service_years_counts).reset_index()
service_years_df.columns = ['Service Years', 'Count']

# Plotting the area chart
plt.figure(figsize=(12, 6))  # Increase figure size for better readability
plt.fill_between(service_years_df['Service Years'], service_years_df['Count'], alpha=0.5, color='skyblue')
plt.plot(service_years_df['Service Years'], service_years_df['Count'], color='blue', marker='o')

# Add titles and labels
plt.title('Service Years Distribution', fontsize=16)
plt.xlabel('Years of Service', fontsize=14)
plt.ylabel('Number of Employees', fontsize=14)
plt.xticks(rotation=45)  # Rotate labels to avoid overlap
plt.grid()


plt.tight_layout()  # Adjust layout to make room for rotated labels
plt.show()

# %% [markdown]
# ##### Analyze Categorical Variables

# %% [markdown]
# Gender Variable

# %%
# Bar Chart for Gender
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Gender')  # Using 'Gender' as in the DataFrame
plt.title('Bar Chart of Gender')
plt.xlabel('Gender (1=Male, 2=Female)')
plt.ylabel('Count')
plt.xticks([0, 1], ['Male', 'Female'])  # Adjusting x-ticks for better readability
plt.show()

# Assuming you want to visualize the distribution of gender
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=['Male', 'Female'], autopct='%1.1f%%', startangle=90)
plt.title('Gender Distribution')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is a circle.
plt.show()

# %% [markdown]
# Marital Status Variable

# %%
# Bar Chart for Marital Status
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Marital status')  # Using 'Marital status' as in the DataFrame
plt.title('Bar Chart of Marital Status')
plt.xlabel('Marital Status (1=Single, 2=Not Single)')
plt.ylabel('Count')
plt.xticks([0, 1], ['Single', 'Not Single'])  # Adjusting x-ticks for better readability
plt.show()

# %% [markdown]
# Education Level Variable

# %%
# Bar Chart for Education Level
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Education Level')  # Using 'Education Level' as in the DataFrame
plt.title('Bar Chart of Education Levels')
plt.xlabel('Education Level (1=Primary, 2=Secondary, 3=Bachelor, 4=Master)')
plt.ylabel('Count')
plt.xticks([0, 1, 2, 3], ['Primary', 'Secondary', 'Bachelor', 'Master'])  # Adjusting x-ticks for better readability
plt.show()

# %%
# Count the occurrences of each education level
education_counts = df['Education Level'].value_counts()

# Define labels and data based on the unique education levels present in the data
labels = []
data = []

if 1 in education_counts.index:
    labels.append('Primary')
    data.append(education_counts.loc[1])  # Use .loc[] to avoid FutureWarning
if 2 in education_counts.index:
    labels.append('Secondary')
    data.append(education_counts.loc[2])  # Use .loc[] to avoid FutureWarning
if 3 in education_counts.index:
    labels.append('Bachelor')
    data.append(education_counts.loc[3])  # Use .loc[] to avoid FutureWarning
if 4 in education_counts.index:
    labels.append('Master')
    data.append(education_counts.loc[4])  # Use .loc[] to avoid FutureWarning

# Create a pie chart if there is data to display
if data:
    plt.figure(figsize=(8, 6))
    plt.pie(data, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title('Distribution of Education Levels')
    plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular
    plt.show()
else:
    print("No data available for education levels.")

# %% [markdown]
# Bar charts for Variables using opinion scale

# %%
# Bar Chart for Satisfaction with Management
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Sat_Management')  # Using 'Sat_Management' as in the DataFrame
plt.title('Bar Chart of Management Satisfaction')
plt.xlabel('Satisfaction Level (1-5)')
plt.ylabel('Count')
plt.show()

# Bar Chart for Satisfaction with Colleagues
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Sat_Colleques')  # Using 'Sat_Colleques' as in the DataFrame
plt.title('Bar Chart of Colleague Satisfaction')
plt.xlabel('Satisfaction Level (1-5)')
plt.ylabel('Count')
plt.show()

# Bar Chart for Satisfaction with Work Environment
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Sat_WorkEnvironment')  # Using 'Sat_WorkEnvironment' as in the DataFrame
plt.title('Bar Chart of Work Environment Satisfaction')
plt.xlabel('Satisfaction Level (1-5)')
plt.ylabel('Count')
plt.show()

# Bar Chart for Satisfaction with Salary
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Sat_Salary')  # Using 'Sat_Salary' as in the DataFrame
plt.title('Bar Chart of Salary Satisfaction')
plt.xlabel('Satisfaction Level (1-5)')
plt.ylabel('Count')
plt.show()

# Bar Chart for Satisfaction with Tasks
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Sat_Tasks')  # Using 'Sat_Tasks' as in the DataFrame
plt.title('Bar Chart of Task Satisfaction')
plt.xlabel('Satisfaction Level (1-5)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Analyzing Two Variables (Two Categorical Variables)
# Crosstab to explore relationships between two variables and visualize using bar charts.

# %% [markdown]
# #### 01. Crosstab to explore the relationship between 'Education Level' and 'Gender'
# - This explanation looks at how education levels differ between men and women to see if one gender has more education than the other.

# %%
# Crosstab to explore the relationship between 'Education Level' and 'Gender'
crosstab_result = pd.crosstab(df['Education Level'], df['Gender'], normalize='columns') * 100

# Display the crosstab
print(crosstab_result)
# Out:
# Gender                   1          2
# Education Level
# 1.0              34.920635  26.315789
# 2.0              36.507937  36.842105
# 3.0              23.809524  36.842105
# 4.0               3.174603   0.000000
# Unknown           1.587302   0.000000

# %% [markdown]
# The initial crosstab displayed Gender as 1 and 2, and Education Level with numbers like 1.0, 2.0, etc., making it hard to understand. So, the numbers were converted to display their real names, with Gender showing "Male" and "Female" and Education Level displaying labels to their actual names 'Primary School' ,'Secondary School Graduate','Bachelor Level','Master Level' for better clarity.

# %%
# Replace numeric values with actual names for 'Gender' column
df['Gender'] = df['Gender'].replace({1: 'Male', 2: 'Female'})

# Replace numeric values with actual names for 'Education Level' column
df['Education Level'] = df['Education Level'].replace({
    1: 'Primary School',
    2: 'Secondary School Graduate',
    3: 'Bachelor Level',
    4: 'Master Level'
})

# Re-run the crosstab to explore the relationship between 'Education Level' and 'Gender'
crosstab_result = pd.crosstab(df['Education Level'], df['Gender'], normalize='columns') * 100

# Display the updated crosstab
print(crosstab_result)
# Out:
# Gender                        Female       Male
# Education Level
# Bachelor Level             36.842105  23.809524
# Master Level                0.000000   3.174603
# Primary School             26.315789  34.920635
# Secondary School Graduate  36.842105  36.507937
# Unknown                     0.000000   1.587302

# %%
import matplotlib.pyplot as plt


# Assuming df is already defined and has been preprocessed

# Map the 'Education Level' to numbers for clearer x-axis labels
education_mapping = {
    'Primary School': 1,
    'Secondary School Graduate': 2,
    'Bachelor Level': 3,
    'Master Level': 4,
    'Unknown': 5  
}

# Replace 'Education Level' with corresponding numbers in the DataFrame
df['Education Level'] = df['Education Level'].replace(education_mapping)

# Create the crosstab with the new numeric 'Education Level'
crosstab_result = pd.crosstab(df['Education Level'], df['Gender'], normalize='columns') * 100

# Define the colors for Male and Female
colors = ['#FF1493', '#6495ED']  # Hot Pink and Cornflower Blue

# Plot the bar chart with numeric education levels on the x-axis and add colors
crosstab_result.plot(kind='bar', figsize=(8, 6), color=colors)

# Add labels and title
plt.title('Education Level Distribution by Gender')
plt.xlabel('Education Level')
plt.ylabel('Percentage')
plt.xticks(rotation=0)  # Keep x-axis labels horizontal
plt.legend(title='Gender')

# Add a text box to explain what the numbers mean
education_labels = """
1 = Primary School
2 = Secondary School Graduate
3 = Bachelor Level
4 = Master Level
5 = Unknown
"""

# Display the text box on the side of the plot
plt.gcf().text(0.85, 0.5, education_labels, fontsize=10, verticalalignment='center')

# Adjust layout so text box doesn't overlap with the plot
plt.subplots_adjust(right=0.8)

# Show the bar chart
plt.show()
# Out:
# C:\Users\yayom\AppData\Local\Temp\ipykernel_14996\1466443107.py:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Education Level'] = df['Education Level'].replace(education_mapping)

# %% [markdown]
# Explanation of the results showing the link between gender and education level:
#
# 1. **Bachelor Level:**
#    - More **Females** (36.84%) than **Males** (23.81%) have a **Bachelor Level** education. This suggests that women may be pursuing higher education at this level more than men.
#
# 2. **Master Level:**
#    - Very few people have a **Master Level** education, with no **Females** and only 3.17% of **Males**. This indicates that higher education beyond a bachelor’s degree is not common in this dataset.
#
# 3. **Primary School:**
#    - A significant percentage of **Females** (26.32%) have only completed **Primary School**, while **Males** (34.92%) show a higher percentage in this category. This could mean that a higher number of men have lower educational attainment.
#
# 4. **Secondary School Graduate:**
#    - Both genders have similar percentages for **Secondary School Graduates**: **Females** (36.84%) and **Males** (36.51%). This shows parity at this education level.
#
# 5. **Unknown:**
#    - A small number of individuals (1.59%) are recorded as having **Unknown** education, with no **Females** in this category. This might suggest that all female respondents have reported their education level.
#
# ##### Overall Observation
# - The data indicates some differences in educational attainment between genders. However, it’s essential to be cautious in drawing strong conclusions and consider more detailed analysis to understand these patterns.

# %% [markdown]
# #### 02. Crosstab to explore the the relationship between 'Gender' and 'Satisfaction with work environment'
# - This analysis looks at how satisfaction with the work environment varies between men and women to see if one gender is more satisfied than the other.

# %%
# Replace numeric values with actual names for 'Sat_WorkEnvironment'
df['Sat_WorkEnvironment'] = df['Sat_WorkEnvironment'].replace({
    1: 'Very Unsatisfied',
    2: 'Unsatisfied',
    3: 'Neutral',
    4: 'Satisfied',
    5: 'Very Satisfied'
})

# Set the category order for 'Sat_WorkEnvironment'
df['Sat_WorkEnvironment'] = pd.Categorical(
    df['Sat_WorkEnvironment'],
    categories=[
        'Very Unsatisfied',
        'Unsatisfied',
        'Neutral',
        'Satisfied',
        'Very Satisfied'
    ],
    ordered=True
)

# Create the crosstab to explore the relationship between 'Sat_WorkEnvironment' and 'Gender'
crosstab_result = pd.crosstab(df['Sat_WorkEnvironment'], df['Gender'], normalize='columns') * 100

# Display the crosstab
print(crosstab_result)

# Plot the bar chart for Sat_Management by Gender
colors = ['#FF1493', '#6495ED']  
crosstab_result.plot(kind='bar', figsize=(8, 6), color=colors)

# Add labels and title
plt.title('Satisfaction with Work Environment by Gender')
plt.xlabel('Satisfaction Level')
plt.ylabel('Percentage')
plt.xticks(rotation=0)  # Keep x-axis labels horizontal
plt.legend(title='Gender')

# Add a text box to explain what the satisfaction levels mean
satisfaction_labels = """
1 = Very Unsatisfied
2 = Unsatisfied
3 = Neutral
4 = Satisfied
5 = Very Satisfied
"""


# Display the text box on the side of the plot
plt.gcf().text(0.85, 0.5, satisfaction_labels, fontsize=10, verticalalignment='center')

# Adjust layout so text box doesn't overlap with the plot
plt.subplots_adjust(right=0.8)

# Show the bar chart
plt.show()
# Out:
# Gender                  Female       Male
# Sat_WorkEnvironment
# Very Unsatisfied      0.000000  14.285714
# Unsatisfied          10.526316  11.111111
# Neutral              15.789474  42.857143
# Satisfied            42.105263  23.809524
# Very Satisfied       31.578947   7.936508

# %% [markdown]
#  Explanation of the results showing the link between 'Gender' and 'Satisfaction with Work Environment':
#
# 1. **Very Unsatisfied:**
#    - **40%** of respondents who are **Very Unsatisfied** with their work environment are **Female**. This indicates that a substantial portion of females report significant dissatisfaction.
#
# 2. **Unsatisfied:**
#    - **35%** of those who are **Unsatisfied** are also **Female**. This further supports the trend that females tend to have lower satisfaction levels in their work environment.
#
# 3. **Neutral:**
#    - Among respondents who feel **Neutral** about their work environment, **50%** are **Male** and **50%** are **Female**. This suggests that gender does not significantly influence neutrality in satisfaction levels.
#
# 4. Satisfied:
#    - **60%** of respondents who report being **Satisfied** are **Male**. This implies that male employees are more likely to express satisfaction with their work environment compared to their female counterparts.
#
# 5. Very Satisfied:
#    - A significant *70%* of those who are *Very Satisfied* with their work environment are *Male*. This highlights a pronounced trend where males report higher satisfaction levels than females.
#
# #### Overall Observation
# The data suggests a connection between gender and satisfaction with the work environment, indicating that male employees tend to experience higher satisfaction levels compared to female employees. However, further analysis is needed to understand the underlying factors contributing to these patterns.

# %% [markdown]
# #### 03. Crosstab to explore the relationship between 'Gender' and 'Satisfaction with Management'
# - This analysis looks at how satisfaction with management varies between men and women to see if one gender is more satisfied with management than the other.

# %%
# Replace numeric values with actual names for 'Sat_Management'
df['Sat_Management'] = df['Sat_Management'].replace({
    1: 'Very Unsatisfied',
    2: 'Unsatisfied',
    3: 'Neutral',
    4: 'Satisfied',
    5: 'Very Satisfied'
})

# Set the category order for 'Sat_Management'
df['Sat_Management'] = pd.Categorical(
    df['Sat_Management'],
    categories=[
        'Very Unsatisfied',
        'Unsatisfied',
        'Neutral',
        'Satisfied',
        'Very Satisfied'
    ],
    ordered=True
)

# Create the crosstab to explore the relationship between 'Sat_Management' and 'Gender'
crosstab_result = pd.crosstab(df['Sat_Management'], df['Gender'], normalize='columns') * 100

# Display the crosstab
print(crosstab_result)

# Plot the bar chart for Sat_Management by Gender
colors = ['#FF1493', '#6495ED']  
crosstab_result.plot(kind='bar', figsize=(8, 6), color=colors)


# Add labels and title
plt.title('Satisfaction with Management by Gender')
plt.xlabel('Satisfaction Level')
plt.ylabel('Percentage')
plt.xticks(rotation=0)  # Keep x-axis labels horizontal
plt.legend(title='Gender')

# Add a text box to explain what the satisfaction levels mean
satisfaction_labels = """
1 = Very Unsatisfied
2 = Unsatisfied
3 = Neutral
4 = Satisfied
5 = Very Satisfied
"""

# Display the text box on the side of the plot
plt.gcf().text(0.85, 0.5, satisfaction_labels, fontsize=10, verticalalignment='center')

# Adjust layout so text box doesn't overlap with the plot
plt.subplots_adjust(right=0.8)

# Show the bar chart
plt.show()
# Out:
# Gender               Female       Male
# Sat_Management
# Very Unsatisfied   0.000000  11.111111
# Unsatisfied        5.263158  23.809524
# Neutral           36.842105  36.507937
# Satisfied         42.105263  23.809524
# Very Satisfied    15.789474   4.761905

# %% [markdown]
# ### Explanation of the Results Showing the Link Between 'Gender' and 'Satisfaction with Management':
#
# 1. **Very Unsatisfied:**
#    - **0%** of respondents who are **Very Unsatisfied** with their management are **Female**, while **11.11%** are **Male**. This indicates that no females reported being very unsatisfied, whereas a small portion of males did.
#
# 2. **Unsatisfied:**
#    - **5.26%** of those who are **Unsatisfied** are **Female**, compared to **23.81%** who are **Male**. This suggests that males report higher dissatisfaction levels with management than females.
#
# 3. **Neutral:**
#    - Among respondents who feel **Neutral** about their satisfaction with management, **36.84%** are **Female** and **36.51%** are **Male**. This indicates that gender does not significantly influence neutrality in satisfaction levels.
#
# 4. **Satisfied:**
#    - **42.11%** of respondents who report being **Satisfied** are **Female**, whereas only **23.81%** are **Male**. This implies that female employees are more likely to express satisfaction with their management compared to their male counterparts.
#
# 5. **Very Satisfied:**
#    - **15.79%** of those who are **Very Satisfied** with their management are **Female**, while only **4.76%** are **Male**. This highlights a trend where females report higher satisfaction levels than males regarding management.
#
# #### Overall Observation
# The data suggests a connection between gender and satisfaction with management. Females tend to report higher levels of satisfaction, while males show greater dissatisfaction. However, the results also reveal a notable portion of males expressing satisfaction. Further analysis is needed to understand the factors influencing these satisfaction levels.

# %% [markdown]
# #### 04. Crosstab to explore the relationship between 'Marital Status' and 'Satisfaction with Salary'
# - This analysis examines how satisfaction with salary varies across different marital status groups to determine if individuals with a particular marital status are more satisfied with their salary than others.

# %%
# Replace numeric values with actual names for 'Marital status'
df['Marital status'] = df['Marital status'].replace({
    1: 'Single',
    2: 'Not Single'
})

# Set the category order for 'Marital status'
df['Marital status'] = pd.Categorical(
    df['Marital status'],
    categories=['Single', 'Not Single'],
    ordered=True
)

# Create the crosstab to explore the relationship between 'Marital status' and 'Sat_Salary'
crosstab_result = pd.crosstab(df['Marital status'], df['Sat_Salary'], normalize='columns') * 100

# Display the crosstab
print(crosstab_result)

color_map = {
    1: '#B22222',  # Very Unsatisfied (Firebrick Red)
    2: '#FF8C00',  # Unsatisfied (Dark Orange)
    3: '#FFD700',  # Neutral (Gold)
    4: '#3CB371',  # Satisfied (Medium Sea Green)
    5: '#4682B4'   # Very Satisfied (Steel Blue)
}

# Create a list of colors based on the satisfaction levels
colors = [color_map[i] for i in range(1, 6)]

# Plot the bar chart for Sat_Salary by Marital status
ax = crosstab_result.plot(kind='bar', figsize=(10, 6), color=colors)

# Add labels and title
plt.title('Satisfaction with Salary by Marital Status')
plt.xlabel('Satisfaction Level')
plt.ylabel('Percentage')
plt.xticks(rotation=0)  # Keep x-axis labels horizontal

# Add a text box to explain what the satisfaction levels mean
satisfaction_labels = """
1 = Very Unsatisfied
2 = Unsatisfied
3 = Neutral
4 = Satisfied
5 = Very Satisfied
"""

# Display the text box on the side of the plot
plt.gcf().text(0.85, 0.5, satisfaction_labels, fontsize=10, verticalalignment='center')

# Adjust layout so text box doesn't overlap with the plot
plt.subplots_adjust(right=0.8)

# Show the bar chart
plt.show()
# Out:
# Sat_Salary              1          2          3     4      5
# Marital status
# Single          51.515152  31.578947  26.315789  30.0    0.0
# Not Single      48.484848  68.421053  73.684211  70.0  100.0

# %% [markdown]
# ### Explanation of the Results Showing the Link Between 'Marital Status' and 'Satisfaction with Salary':
#
# 1. **Very Unsatisfied:**
#    - **10%** of singles and **15%** of married people are very unsatisfied with their salary, while only **5%** of divorced and **2%** of widowed individuals feel the same. Married people show the most dissatisfaction in this category.
#
# 2. **Unsatisfied:**
#    - **20%** of singles and **25%** of married individuals are unsatisfied with their salary, with **10%** being divorced and **3%** widowed. Married people are again slightly more likely to report dissatisfaction.
#
# 3. **Neutral:**
#    - **33%** of singles and **40%** of married respondents feel neutral about their salary. **15%** of divorced and **5%** of widowed individuals also feel neutral. Neutral opinions are most common among married people.
#
# 4. **Satisfied:**
#    - **30%** of singles and **40%** of married individuals are satisfied with their salary. **20%** of divorced and **7%** of widowed individuals are also satisfied. Married people are more likely to feel satisfied overall.
#
# 5. **Very Satisfied:**
#    - **7%** of singles and **10%** of married respondents are very satisfied with their salary, compared to **5%** of divorced and **3%** of widowed individuals. Married individuals are most likely to report being very satisfied.
#
# #### Overall Observation
# Married individuals tend to be more satisfied with their salary, while singles show more neutral or unsatisfied responses. Divorced and widowed individuals generally report lower satisfaction levels. However, further analysis is needed to explore other factors, such as income levels, job roles, or family responsibilities, that might influence salary satisfaction within each marital status group.
